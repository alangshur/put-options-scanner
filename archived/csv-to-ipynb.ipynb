# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
df = pd.read_csv('scans/2020-08-04.csv')
df = df.sort_values('adj_profit', ascending=False)
df
# Out:
#     Unnamed: 0 symbol  udl_price         exp  dte  s_strike  l_strike  width  \
# 13          13    INO    20.5300  2020-09-18   45      17.0      13.0    4.0
# 10          10    INO    20.5300  2020-09-18   45      16.0      13.0    3.0
# 14          14    INO    20.5300  2020-09-18   45      17.0      14.0    3.0
# 8            8    INO    20.5300  2020-09-18   45      15.0      13.0    2.0
# 30          30   SRNE    10.9050  2020-09-18   45       9.0       6.0    3.0
# 31          31   SRNE    10.9050  2020-09-18   45       9.0       7.0    2.0
# 11          11    INO    20.5300  2020-09-18   45      16.0      14.0    2.0
# 51          51    NIO    13.8099  2020-09-18   45      12.0      10.0    2.0
# 28          28   SRNE    10.9050  2020-09-18   45       9.0       5.0    4.0
# 29          29   SRNE    10.9050  2020-09-18   45       9.0       5.5    3.5
# 50          50    NIO    13.8099  2020-09-18   45      12.0       9.0    3.0
# ...

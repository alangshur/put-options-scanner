# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
df = pd.read_csv('scans/2020-07-20.csv')
df = df[df.symbol == 'SRNE']
df = df.sort_values('rr_percent', ascending=False)
df
# Out:
#      Unnamed: 0 symbol  udl_price         exp  dte  s_strike  l_strike  width  \
# 141         141   SRNE     8.1223  2020-09-18   60       6.0       5.0    1.0
# 140         140   SRNE     8.1223  2020-09-18   60       6.0       4.5    1.5
# 142         142   SRNE     8.1223  2020-09-18   60       6.0       5.5    0.5
# 139         139   SRNE     8.1223  2020-09-18   60       6.0       4.0    2.0
# 138         138   SRNE     8.1223  2020-09-18   60       6.0       3.5    2.5
#
#      premium  max_loss  be_price  adj_profit  rr_percent  iv_z_score  \
# 141     45.0      55.0      5.55      20.777      81.818       0.372
# 140     60.0      90.0      5.40      23.666      66.667       0.372
# 142     20.0      30.0      5.80       7.889      66.667       0.372
# 139     75.0     125.0      5.25      26.555      60.000       0.372
# 138     85.0     165.0      5.15      24.444      51.515       0.372
#
#      strad_z_score  s_delta  l_delta
# 141          0.403   24.223   16.574
# ...
